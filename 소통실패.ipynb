# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
disto = pd.read_excel('/content/drive/My Drive/소통형도서관_프로젝트/자료/대출목록_20181231 (1).xlsx')
disto.columns
# Out:
# Index(['번호', '학과', '등록번호', '청구기호', '서명', '저자', '대출일'], dtype='object')

# %%
disto.info
# Out:
# <bound method DataFrame.info of          번호                      학과  ...               저자       대출일
# 0         1                   국어교육과  ...              윤후명  20180905
# 1         2                   국어교육과  ...              윤후명  20181022
# 2         3                   국어교육과  ...              윤후명  20181010
# 3         4                    행정학과  ...       알포드, 로버트 R  20181015
# 4         5                    교육학과  ...              계용묵  20180907
# 5         6                  도서관회원증  ...              이호재  20181004
# 6         7               국어국문·창작학과  ...              이인영  20181018
# 7         8                    인문학부  ...             판원의종  20180625
# 8         9                   국어교육과  ...         순복음교육연구소  20181121
# 9        10                  조형예술학부  ...                   20181127
# 10       11                  조형예술학부  ...                   20181127
# 11       12                 기독교상담학과  ...         볼프, H. W  20180703
# ...

# %%
disto.shape
# Out:
# (9999, 7)
